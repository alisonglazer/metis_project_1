# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt 
import pickle

# %%
# Read in the data
with open('data/clean_df.pickle','rb') as read_file:
    clean_df = pickle.load(read_file)

# %%
clean_df
# Out:
#        control_area  unit       scp        station line_name division  \
# 0              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 1              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 2              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 3              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 4              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 5              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 6              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 7              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 8              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 9              A002  R051  02-00-00          59 ST   NQR456W      BMT
# 10             A002  R051  02-00-00          59 ST   NQR456W      BMT
# 11             A002  R051  02-00-00          59 ST   NQR456W      BMT
# ...

# %%
station_traffic = clean_df.groupby('station').total_traffic.sum()
top_10_stations = station_traffic.sort_values(ascending=False)[0:11]
print('The 10 stations with the most foot traffic during the sampled weeks are')
print(top_10_stations)
# Out:
# The 10 stations with the most foot traffic during the sampled weeks are
# station
# 34 ST-PENN STA     5284002.0
# 23 ST              3929282.0
# GRD CNTRL-42 ST    3436600.0
# FULTON ST          3378770.0
# 34 ST-HERALD SQ    3285373.0
# TIMES SQ-42 ST     3145469.0
# 42 ST-PORT AUTH    3068688.0
# 86 ST              3043789.0
# 125 ST             3035048.0
# CANAL ST           2635121.0
# 59 ST              2554838.0
# Name: total_traffic, dtype: float64

# %%
clean_df.groupby(['weekday','hour','station'])[['entry_counts','exit_counts','total_traffic']].mean()
# Out:
#                               entry_counts  exit_counts  total_traffic
# weekday hour station
# 0       0    1 AV               224.950000   234.150000     459.100000
#              103 ST             107.833333   127.433333     235.266667
#              103 ST-CORONA       89.666667   226.333333     316.000000
#              104 ST              11.166667    18.277778      29.444444
#              110 ST              89.583333   170.916667     260.500000
#              111 ST              33.678571    91.428571     125.107143
#              116 ST              65.363636    68.000000     133.363636
#              116 ST-COLUMBIA     66.250000    47.416667     113.666667
#              121 ST              13.000000    15.727273      28.727273
#              125 ST             118.197674   128.337209     246.534884
#              135 ST              43.704545    36.977273      80.681818
#              137 ST CITY COL     51.500000   137.950000     189.450000
# ...

# %%
# See which stations are most trafficked on weekday mornings

# Look only at weekdays in the morning (from 6AM to 11AM)
am_weekday_df = weekdays_df[np.logical_and(clean_df.weekday<=4,np.logical_and(clean_df.hour<=11,clean_df.hour>=6))]

# See which stations have the most traffic on weekdays in the morning
am_weekday_stations = am_weekday_df.groupby('station').total_traffic.mean().sort_values(ascending=False)
plt.bar(am_weekday_stations[am_weekday_stations>500].index,am_weekday_stations[am_weekday_stations>500].values);
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
def enoughRatings(currGroup):
    return currGroup.Rating.size >= 30
# function must work on a per group basis(accept groupby), and must return a Boolean on a per-group basis, then returns a new DataFrame object sorted into the groups you grouped on initially, with all of the groups removed that don't satisfy the constraints of the function you passed to it
filteredRatings = userGroups.filter(lambda currGroup: currGroup.Rating.size >= 30)
#lambda function is anonymous function, can write function in very brief shorthand
#use lambda when you know you will never need to use it again, but a function is a required input
filteredRatings2 = userGroups.filter(enoughRatings)
print(filteredRatings.shape)
print(filteredRatings2.shape)
